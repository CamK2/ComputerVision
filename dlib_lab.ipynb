# %% [markdown]
# <a href="https://colab.research.google.com/github/CamK2/ComputerVision/blob/main/dlib_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#grab an image

# !wget "https://bellard.org/bpg/lena15.jpg"
# Out:
# --2022-11-30 18:07:21--  https://bellard.org/bpg/lena15.jpg
# Resolving bellard.org (bellard.org)... 51.15.168.198
# Connecting to bellard.org (bellard.org)|51.15.168.198|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15097 (15K) [image/jpeg]
# Saving to: ‘lena15.jpg’
#
# lena15.jpg          100%[===================>]  14.74K  --.-KB/s    in 0.09s
#
# 2022-11-30 18:07:22 (164 KB/s) - ‘lena15.jpg’ saved [15097/15097]

# %%
# !mv 'lena15.jpg' 'test.jpg'
# !ls
# Out:
# sample_data  test.jpg  test.png

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('test.jpg')
plt.imshow(img)
plt.show()

# %%
import dlib
img = dlib.load_rgb_image('test.jpg')
