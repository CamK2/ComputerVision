# %% [markdown]
# <a href="https://colab.research.google.com/github/CamK2/ComputerVision/blob/main/gray.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
print('Done')
# Out:
# Done

# %%
x = cv2.imread('c.png')
x = cv2.cvtColor(x,cv2.COLOR_BGR2RGB)
print('Shape of x:', x.shape)
for yi in range(x.shape[0]):
  for xi in range(x.shape[1]):
    for ci in range(x.shape[2]):
      if x[yi,xi,ci] >= 128:
        x[yi,xi,ci] = 255
      else:
        x[yi,xi,ci] = 0

#cv2.imwrite('fname.jpg',x)
plt.imshow(x)
# Out:
# Shape of x: (674, 754, 3)

# %%
x0 = x.copy()

for yi in range(x.shape[0]):
  for xi in range(x.shape[1]):
    for ci in range(x.shape[2]):
    # blur by 3 pixels
      x[yi,xi,ci] = int((x0[yi,xi,ci]/3 + x0[yi,xi,ci]/3 + x0[yi,xi,ci])/3)

    #  move right/left 
    #  x[yi,xi,ci] = x0[yi,xi+rs,ci]
    
    # invert y
    #  x[yi,xi,ci] = x0[x.shape[0]-1-yi,xi,ci]
                 
plt.imshow(x0)

# %%
a = [1,2,3]
for i in range(len(a)):
  print(a[len(a)-1-i])
# Out:
# 3
# 2
# 1
